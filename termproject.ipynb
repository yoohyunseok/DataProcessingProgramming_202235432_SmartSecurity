# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\new\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataset = pd.read_csv("C:/Users/UserName/Desktop/termproject/dataset/automobile/imports-85.data")

# %%
dataset
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %% [markdown]
# 컬럼 이름 변경

# %%
dataset.rename(columns = {"3":"symboling", "?":"normalized-losses", "alfa-romero":"make", "gas":"fuel-type", "std":"aspiration", "two":"num-of-doors", "convertible":"body-style", "rwd":"drive-wheels", "front":"engine-location", "88.60":"wheel-base", "168.80":"length", "64.10":"width", "48.80":"height", "2548":"curb-weight", "dohc":"engine-type", "four":"num-of-cylinders", "130":"engine-size", "mpfi":"fuel-system", "3.47":"bore", "2.68":"stroke", "9.00":"compression-ratio", "111":"horsepower", "5000":"peak-rpm", "21":"city-mpg", "27":"highway-mpg", "13495":"price"}, inplace = True)

# %%
dataset.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
dataset
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# <h2>1. 결측치, 이상치 확인 및 처리</h2>

# %%
dataset.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
dataset = dataset.drop("normalized-losses", axis = 1)#?라는 값이 존재하여 normalized-lossses를 drop 하였습니다.

# %%
dataset.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# <h2>2. 레이블 값 확인 (그래프 및 수치)</h2>

# %%
data1 = dataset['engine-size']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('engine-size')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['city-mpg']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('city-mpg')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['highway-mpg']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('highway-mpg')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['horsepower']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('horsepower')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['length']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('length')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['width']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('width')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['height']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('height')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = dataset['curb-weight']
Price = dataset['price']

plt.figure(figsize = (10, 4))
plt.scatter(data1, Price)

plt.xlabel('curb-weight')
plt.ylabel('price')
plt.title('automobile fuel type-price Scatter Graph')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h2>3. feature 등의 상관관계</h2>

# %%
df_corr=dataset.corr()

#히트맵
plt.figure(figsize=(8,8))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
ndf = dataset[['city-mpg', 'highway-mpg', 'engine-size', 'length', 'width', 'height']]

# %%
fig = sns.pairplot(ndf)

# %% [markdown]
# <h2>4. 새로운 데이터 프레임 생성, 그룹별</h2>

# %%
new_df = dataset[['length', 'width', 'city-mpg', 'highway-mpg', 'price']]

# %%
plt.boxplot([new_df['length'], new_df['width']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2970c0bbc70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x297099a3190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2970c0bbb50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x297099a3fa0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x297099a3a90>,
# ...
#  'means': []}

# %%
new_df.width.max()
# Out:
# 72.3

# %%
new_df = new_df[new_df.width<70]
new_df.width.max()
# Out:
# 69.6

# %%
plt.boxplot([new_df['length'], new_df['width']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29709602f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x297095fd4f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29709602c70>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x297095fda90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x297095fdd60>,
# ...
#  'means': []}

# %%
new_df.length.max()
# Out:
# 199.6

# %%
new_df.length.min()
# Out:
# 141.1

# %%
new_df = new_df[new_df.length>150]
new_df = new_df[new_df.length<195]

# %%
plt.boxplot([new_df['length'], new_df['width']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2970a0d5280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2970a0d5910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29709a53f70>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2970a0d5fd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2970a0fd100>,
# ...
#  'means': []}

# %%
plt.boxplot([new_df['city-mpg'], new_df['highway-mpg']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2970a16ebe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2970a16e790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2970a16e3d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2970a163910>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2970a163460>,
# ...
#  'means': []}

# %% [markdown]
# <h2>6. 히스토그램</h2>

# %%
setosa_SepalWidth = new_df.loc[:, ['length', 'width']]
virginia_SepalWidth = new_df.loc[:, ['city-mpg', 'highway-mpg']]

plt.figure(figsize=(10, 6))
plt.hist(setosa_SepalWidth['length'], bins = 5, alpha = 0.5, label = 'length', color = 'r')
plt.hist(setosa_SepalWidth['width'], bins = 5, alpha = 0.5, label = 'width', color = 'b')

plt.xlabel('Sepal')
plt.ylabel('Width')
plt.title('Iris SEpal group histogram')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10, 6))
plt.hist(virginia_SepalWidth['city-mpg'], bins = 5, alpha = 0.5, label = 'city', color = 'r')
plt.hist(virginia_SepalWidth['highway-mpg'], bins = 5, alpha = 0.5, label = 'highway', color = 'b')

plt.xlabel('Sepal')
plt.ylabel('Width')
plt.title('Iris SEpal group histogram')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h2>7. (length, width) (highway-mpg, city-mpg)로 price 회귀 분석 결과 비교</h2>

# %% [markdown]
# #LR회귀 length, width로 price 예측

# %%
condition = (new_df['price'] != '?')

# %%
from sklearn.model_selection import train_test_split
x_data=new_df.loc[condition, ['length', 'width']]
y_data=new_df.loc[condition, 'price']
X_train, X_test, y_train, y_test=train_test_split(x_data,
                                                  y_data,
                                                  test_size=0.25,
                                                  shuffle=True,
                                                  random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (131, 2) (131,)
# (44, 2) (44,)

# %%
X_train.head()
# Out:
#      length  width
# 126   168.9   65.0
# 181   171.7   65.5
# 188   159.3   64.2
# 99    173.4   65.2
# 137   156.9   63.4

# %%
y_train.head()
# Out:
# 126    34028
# 181     7775
# 188    11595
# 99      9549
# 137     5118
# Name: price, dtype: object

# %%
X_test.head()
# Out:
#      length  width
# 185   171.7   65.5
# 174   175.6   66.5
# 130   176.8   66.6
# 156   166.3   64.4
# 170   176.2   65.6

# %%
y_test.head()
# Out:
# 185     8495
# 174     9988
# 130     9895
# 156     7198
# 170    11549
# Name: price, dtype: object

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print("회귀계수(기울기):", np.round(lr.coef_, 1)) #np: numpy, coef_: 피처에 대한 회귀 계수 값
print("상수항(절편):", np.round(lr.intercept_, 1))  #intercept_: 상수항(절편) 값
# Out:
# 회귀계수(기울기): [ 212.1 1269.5]
# 상수항(절편): -107515.5

# %%
y_preds = lr.predict(X_test)
print(X_train.shape, X_test.shape)
# Out:
# (131, 2) (44, 2)

# %%
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)
print(f'MSE : {mse:.3f}, RMSE: {rmse:.3f}')
print(f'Variance score : {r2_score(y_test, y_preds):.3f}')
# Out:
# MSE : 8990504.793, RMSE: 2998.417
# Variance score : 0.315

# %%
print("절편 값:", lr.intercept_) # y축 절편값

# 회귀 계수(coefficient) : 독립변수의 변화에 따라 종속변수에 미치는 영향력이 크기
print("회귀계수:", np.round(lr.coef_,1))
# Out:
# 절편 값: -107515.50163101178
# 회귀계수: [ 212.1 1269.5]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ly_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2998.4170478048954

# %% [markdown]
# #DT회귀 length, width로 price 예측

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(dy_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 1961.6940402459045

# %% [markdown]
# #RF회귀 length, width로 price 예측

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ry_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 1627.6724744551607

# %% [markdown]
# #SVM 회귀 length, width로 price 예측

# %%
from sklearn.svm import SVR

model = SVR()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

sy_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(sy_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 3733.0100277319084

# %% [markdown]
# #LR회귀 city-mpg, highway-mpg로 price 예측

# %%
from sklearn.model_selection import train_test_split
x_data=new_df.loc[condition, ['city-mpg', 'highway-mpg']]
y_data=new_df.loc[condition, 'price']
X_train, X_test, y_train, y_test=train_test_split(x_data,
                                                  y_data,
                                                  test_size=0.25,
                                                  shuffle=True,
                                                  random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (131, 2) (131,)
# (44, 2) (44,)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print("회귀계수(기울기):", np.round(lr.coef_, 1)) #np: numpy, coef_: 피처에 대한 회귀 계수 값
print("상수항(절편):", np.round(lr.intercept_, 1))  #intercept_: 상수항(절편) 값
# Out:
# 회귀계수(기울기): [-1367.9   601.6]
# 상수항(절편): 28354.9

# %%
y_preds = lr.predict(X_test)
print(X_train.shape, X_test.shape)
# Out:
# (131, 2) (44, 2)

# %%
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)
print(f'MSE : {mse:.3f}, RMSE: {rmse:.3f}')
print(f'Variance score : {r2_score(y_test, y_preds):.3f}')
# Out:
# MSE : 16326875.261, RMSE: 4040.653
# Variance score : -0.243

# %%
print("절편 값:", lr.intercept_) # y축 절편값

# 회귀 계수(coefficient) : 독립변수의 변화에 따라 종속변수에 미치는 영향력이 크기
print("회귀계수:", np.round(lr.coef_,1))
# Out:
# 절편 값: 28354.942955097595
# 회귀계수: [-1367.9   601.6]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ly_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 4040.652826031178

# %% [markdown]
# #DT회귀 city-mpg, highway-mpg로 price 예측

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(dy_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 4118.006914362541

# %% [markdown]
# #RF회귀 city-mpg, highway-mpg로 price 예측

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ry_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 3789.1496026117707

# %% [markdown]
# #SVM회귀 city-mpg, highway-mpg로 price 예측

# %%
model = SVR()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

sy_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(sy_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 3733.0100277319084
