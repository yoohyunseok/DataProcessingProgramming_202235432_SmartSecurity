# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/UserName/Desktop/2-2학기/스보/데이터 처리 프로그래밍/abalone/abalone.data")

# %%
df
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# M         0
# 0.455     0
# 0.365     0
# 0.095     0
# 0.514     0
# 0.2245    0
# 0.101     0
# 0.15      0
# 15        0
# dtype: int64

# %% [markdown]
# <h2>#column명 설정</h2>

# %%
df.columns = ["Sex", "Length",	"Diam", "Height", "Whole", "Shucked", "Viscera", "Shell", "Rings"]

# %%
df
# Out:
#      Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0      M   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 1      F   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 2      M   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 3      I   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# 4      I   0.425  0.300   0.095  0.3515   0.1410   0.0775  0.1200      8
# ...   ..     ...    ...     ...     ...      ...      ...     ...    ...
# 4171   F   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4172   M   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4173   M   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4174   F   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4175   M   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4176 rows x 9 columns]

# %%
import seaborn as sns

plt.boxplot([df['Diam'], df['Length']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x162a71aab80>,
#   <matplotlib.lines.Line2D at 0x162a71aae50>,
#   <matplotlib.lines.Line2D at 0x162a71b7f70>,
#   <matplotlib.lines.Line2D at 0x162a71c4280>],
#  'caps': [<matplotlib.lines.Line2D at 0x162a71b7160>,
#   <matplotlib.lines.Line2D at 0x162a71b7430>,
#   <matplotlib.lines.Line2D at 0x162a71c4550>,
#   <matplotlib.lines.Line2D at 0x162a71c4820>],
#  'boxes': [<matplotlib.lines.Line2D at 0x162a71aa8b0>,
#   <matplotlib.lines.Line2D at 0x162a71b7ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x162a71b7700>,
#   <matplotlib.lines.Line2D at 0x162a71c4af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x162a71b79d0>,
#   <matplotlib.lines.Line2D at 0x162a71c4dc0>],
#  'means': []}

# %% [markdown]
# #이상치 제거

# %%
df.Diam.min()
# Out:
# 0.055

# %%
df.Length.min()
# Out:
# 0.075

# %%
df = df[df.Diam>0.07]
df.Diam.min()
# Out:
# 0.09

# %%
df = df[df.Length>0.13]
df.Length.min()
# Out:
# 0.135

# %%
plt.boxplot([df['Diam'], df['Length']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x162a7361880>,
#   <matplotlib.lines.Line2D at 0x162a7361b50>,
#   <matplotlib.lines.Line2D at 0x162a736fc70>,
#   <matplotlib.lines.Line2D at 0x162a736ff40>],
#  'caps': [<matplotlib.lines.Line2D at 0x162a7361e20>,
#   <matplotlib.lines.Line2D at 0x162a736f130>,
#   <matplotlib.lines.Line2D at 0x162a737f250>,
#   <matplotlib.lines.Line2D at 0x162a737f520>],
#  'boxes': [<matplotlib.lines.Line2D at 0x162a73615b0>,
#   <matplotlib.lines.Line2D at 0x162a736f9a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x162a736f400>,
#   <matplotlib.lines.Line2D at 0x162a737f7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x162a736f6d0>,
#   <matplotlib.lines.Line2D at 0x162a737fac0>],
#  'means': []}

# %%
df.groupby('Rings').count()
# Out:
#        Sex  Length  Diam  Height  Whole  Shucked  Viscera  Shell
# Rings
# 2        1       1     1       1      1        1        1      1
# 3       13      13    13      13     13       13       13     13
# 4       56      56    56      56     56       56       56     56
# 5      115     115   115     115    115      115      115    115
# 6      259     259   259     259    259      259      259    259
# 7      391     391   391     391    391      391      391    391
# 8      568     568   568     568    568      568      568    568
# 9      689     689   689     689    689      689      689    689
# 10     634     634   634     634    634      634      634    634
# 11     487     487   487     487    487      487      487    487
# 12     267     267   267     267    267      267      267    267
# 13     203     203   203     203    203      203      203    203
# 14     126     126   126     126    126      126      126    126
# 15     102     102   102     102    102      102      102    102
# 16      67      67    67      67     67       67       67     67
# 17      58      58    58      58     58       58       58     58
# 18      42      42    42      42     42       42       42     42
# 19      32      32    32      32     32       32       32     32
# 20      26      26    26      26     26       26       26     26
# 21      14      14    14      14     14       14       14     14
# 22       6       6     6       6      6        6        6      6
# 23       9       9     9       9      9        9        9      9
# 24       2       2     2       2      2        2        2      2
# 25       1       1     1       1      1        1        1      1
# 26       1       1     1       1      1        1        1      1
# 27       2       2     2       2      2        2        2      2
# 29       1       1     1       1      1        1        1      1

# %%
df.groupby('Rings')['Shucked'].mean()
# Out:
# Rings
# 2     0.004500
# 3     0.013038
# 4     0.025071
# 5     0.061696
# 6     0.123158
# 7     0.182657
# 8     0.293773
# 9     0.387938
# 10    0.447217
# 11    0.503977
# 12    0.472781
# 13    0.434638
# 14    0.427190
# 15    0.404216
# 16    0.421716
# 17    0.467052
# 18    0.446833
# 19    0.440625
# 20    0.458115
# 21    0.447464
# 22    0.405000
# 23    0.399444
# 24    0.600250
# 25    0.426500
# 26    0.384000
# 27    0.539000
# 29    0.705500
# Name: Shucked, dtype: float64

# %%
df.groupby('Rings')['Shucked', 'Whole'].mean()
# Out:
# C:\Users\UserName\AppData\Local\Temp\ipykernel_21436\4003764479.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Rings')['Shucked', 'Whole'].mean()
#         Shucked     Whole
# Rings
# 2      0.004500  0.015000
# 3      0.013038  0.031154
# 4      0.025071  0.060482
# 5      0.061696  0.125500
# 6      0.123158  0.273174
# 7      0.182657  0.397386
# 8      0.293773  0.640753
# 9      0.387938  0.852013
# 10     0.447217  1.008748
# 11     0.503977  1.142559
# 12     0.472781  1.102904
# 13     0.434638  1.075453
# 14     0.427190  1.079992
# 15     0.404216  1.046118
# 16     0.421716  1.133388
# 17     0.467052  1.234328
# 18     0.446833  1.194333
# 19     0.440625  1.166797
# 20     0.458115  1.251750
# 21     0.447464  1.250607
# 22     0.405000  1.221250
# 23     0.399444  1.170389
# 24     0.600250  1.798750
# 25     0.426500  1.406000
# 26     0.384000  1.057500
# 27     0.539000  1.698000
# 29     0.705500  1.807500

# %% [markdown]
# <h2>#Rings 만 빼기</h2>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])

# %%
y = df['Rings']
x = df.drop('Rings', axis = 1)

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.25,random_state=42)



from sklearn.linear_model import LinearRegression



model = LinearRegression()

model.fit(X_train, y_train)



from sklearn.metrics import mean_squared_error



ly_preds = model.predict(X_test)

mse = np.sqrt(mean_squared_error(ly_preds, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.188010943577428

# %% [markdown]
# <h2>#iris</h2>

# %%
df2 = pd.read_csv("C:/Users/UserName/Desktop/2-2학기/스보/데이터 처리 프로그래밍/iris/iris.data")

# %%
df2
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
df2.mean()
# Out:
# C:\Users\UserName\AppData\Local\Temp\ipykernel_21436\3587575296.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.mean()
# 5.1    5.848322
# 3.5    3.051007
# 1.4    3.774497
# 0.2    1.205369
# dtype: float64

# %% [markdown]
# #최빈값 확인

# %%
df2.mode()
# Out:
#    5.1  3.5  1.4  0.2      Iris-setosa
# 0  5.0  3.0  1.5  0.2  Iris-versicolor
# 1  NaN  NaN  NaN  NaN   Iris-virginica

# %%
df2.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]

# %%
df2 = df2.drop('class', axis = 1)

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             4.7          3.2           1.3          0.2
# 2             4.6          3.1           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %%
x = df2.loc[:, ['sepal_length', 'sepal_width', 'petal_length']]
y = df2['petal_width']

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.25,random_state=42)



from sklearn.linear_model import LinearRegression



model = LinearRegression()

model.fit(X_train, y_train)



from sklearn.metrics import mean_squared_error



ly_preds = model.predict(X_test)

mse = np.sqrt(mean_squared_error(ly_preds, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 0.19351440669407016

# %%
df2 = pd.read_csv("C:/Users/UserName/Desktop/2-2학기/스보/데이터 처리 프로그래밍/iris/iris.data")

# %%
df2.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2['class']=le.fit_transform(df2['class'])

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0             4.9          3.0           1.4          0.2      0
# 1             4.7          3.2           1.3          0.2      0
# 2             4.6          3.1           1.5          0.2      0
# 3             5.0          3.6           1.4          0.2      0
# 4             5.4          3.9           1.7          0.4      0
# ..            ...          ...           ...          ...    ...
# 144           6.7          3.0           5.2          2.3      2
# 145           6.3          2.5           5.0          1.9      2
# 146           6.5          3.0           5.2          2.0      2
# 147           6.2          3.4           5.4          2.3      2
# 148           5.9          3.0           5.1          1.8      2
#
# [149 rows x 5 columns]

# %%
x = df2.loc[:, ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df2['class']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((111, 4), (38, 4), (111,), (38,))

# %%
# SVM

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(x_train, y_train)

pred_svm = clf_svm.predict(x_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.9210526315789473
# [[14  0  0]
#  [ 0 14  0]
#  [ 0  3  7]]

# %%
# LR

from sklearn.linear_model import LogisticRegression

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(x_train, y_train)

pred_lr = clf_lr.predict(x_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.8947368421052632
# [[14  0  0]
#  [ 0 13  1]
#  [ 0  3  7]]
# c:\new\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# DT

from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(x_train, y_train)

pred_dt = clf_dt.predict(x_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.868421052631579
# [[14  0  0]
#  [ 0 13  1]
#  [ 0  4  6]]

# %%
# RF

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

print ("\n--- Random Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(x_train, y_train)
pred = rf_clf.predict(x_test)
print(accuracy_score(y_test,pred))
print (confusion_matrix(y_test, pred))
# Out:
# --- Random Forest ---
# 0.868421052631579
# [[14  0  0]
#  [ 0 13  1]
#  [ 0  4  6]]
